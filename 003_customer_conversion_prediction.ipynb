# %%
import pandas as pd 
import os
import numpy as np 
import tensorflow as tf

# %% [markdown]
# Data represents an audioboook app that has 2 years of data from its clients. The
# goal of this project is to predict which customer will convert. target column is generated by taking an additional 6 months of data from the user base and checking which users have converted after the 2 year period.

# %%
df = pd.read_csv(os.path.join('data', 'audiobook_data.csv'))

# %%
df
# Out:
#           id   book_length_(mins)_overal  book_length_(min)_avg  \
# 0        873                      2160.0                   2160
# 1        611                      1404.0                   2808
# 2        705                       324.0                    324
# 3        391                      1620.0                   1620
# 4        819                       432.0                   1296
# ...      ...                         ...                    ...
# 14079  27398                      2160.0                   2160
# 14080  28220                      1620.0                   1620
# 14081  28671                      1080.0                   1080
# 14082  31134                      2160.0                   2160
# 14083  32832                      1620.0                   1620
#
#        price_overall  price_avg  review  review_10_10  minutes_listened  \
# 0              10.13      10.13       0          8.91              0.00
# ...

# %%
df.duplicated().sum()
# Out:
# 0
